# %% [markdown]
# <a href="https://colab.research.google.com/github/riya-nitnaware/riya-nitnaware.ML-LAB/blob/main/prac_6_Riya__ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Practical 6_Riya Nitnaware(CS23015)**
#
# **AIM:- To design and implement an Artificial Neural Network for classification problem and evaluate its learning performance.**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path=("/content/drive/MyDrive/ML_Dataset/churn.csv")
df=pd.read_csv(path)
df.head(5)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df.isnull().any().any()
# Out:
# np.False_

# %%
df.isnull().sum
# Out:
# <bound method DataFrame.sum of       RowNumber  CustomerId  Surname  CreditScore  Geography  Gender    Age  \
# 0         False       False    False        False      False   False  False
# 1         False       False    False        False      False   False  False
# 2         False       False    False        False      False   False  False
# 3         False       False    False        False      False   False  False
# 4         False       False    False        False      False   False  False
# ...         ...         ...      ...          ...        ...     ...    ...
# 9995      False       False    False        False      False   False  False
# 9996      False       False    False        False      False   False  False
# 9997      False       False    False        False      False   False  False
# 9998      False       False    False        False      False   False  False
# 9999      False       False    False        False      False   False  False
#
# ...

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [RowNumber, CustomerId, Surname, CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited]
# Index: []

# %%
x = df.drop(columns=['Exited'])
y = df['Exited']

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
x
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
x=x.iloc[:,3:]

# %%
x.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# 2          1               0        113931.57
# 3          0               0         93826.63
# 4          1               1         79084.10

# %%
x=pd.get_dummies(x,dtype=int)

# %%
x.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# 0               1        101348.88                 1                  0
# 1               1        112542.58                 0                  0
# 2               0        113931.57                 1                  0
# 3               0         93826.63                 1                  0
# 4               1         79084.10                 0                  0
#
#    Geography_Spain  Gender_Female  Gender_Male
# 0                0              1            0
# ...

# %%
x.shape
# Out:
# (10000, 13)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.7,test_size=0.3,random_state=42)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((7000, 13), (3000, 13), (7000,), (3000,))

# %%
#performing feature scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
x_train
# Out:
# array([[-0.34459497, -0.65674999, -0.34217046, ...,  1.73073215,
#          1.09823226, -1.09823226],
#        [-0.09518109, -0.46637979,  0.69816249, ..., -0.57779016,
#          1.09823226, -1.09823226],
#        [-0.94734518, -0.56156489,  0.35138484, ..., -0.57779016,
#         -0.91055421,  0.91055421],
#        ...,
#        [ 0.86090545, -0.08563939, -1.38250341, ..., -0.57779016,
#          1.09823226, -1.09823226],
#        [ 0.15423279,  0.39028611,  1.04494014, ..., -0.57779016,
#         -0.91055421,  0.91055421],
#        [ 0.46600014,  1.1517669 , -1.38250341, ..., -0.57779016,
#         -0.91055421,  0.91055421]])

# %%
x_test
# Out:
# array([[-0.5836166 , -0.65674999, -0.68894811, ..., -0.57779016,
#         -0.91055421,  0.91055421],
#        [-0.30302599,  0.39028611, -1.38250341, ..., -0.57779016,
#         -0.91055421,  0.91055421],
#        [-0.53165538,  0.48547121, -0.34217046, ...,  1.73073215,
#          1.09823226, -1.09823226],
#        ...,
#        [-0.44851742, -0.65674999,  0.69816249, ..., -0.57779016,
#         -0.91055421,  0.91055421],
#        [-0.74989252, -0.75193509, -1.03572576, ..., -0.57779016,
#         -0.91055421,  0.91055421],
#        [-1.23832804, -1.60860099,  1.73849544, ..., -0.57779016,
#          1.09823226, -1.09823226]])

# %%
#importing necessary librarries
import numpy as np
import tensorflow as tf

# %%
#initialising ANN
ann = tf.keras.models.Sequential()

# %%
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

# %%
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

# %%
ann.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %%
ann.compile(optimizer="adam",loss="binary_crossentropy",metrics=['accuracy'])

# %%
ann.fit(x_train,y_train,batch_size=32,epochs=100)
# Out:
# Epoch 1/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7949 - loss: 0.5358
# Epoch 2/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7939 - loss: 0.4653
# Epoch 3/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7932 - loss: 0.4550
# Epoch 4/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7813 - loss: 0.4631
# Epoch 5/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7934 - loss: 0.4415
# Epoch 6/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7927 - loss: 0.4384
# Epoch 7/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7831 - loss: 0.4453
# Epoch 8/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8111 - loss: 0.4224
# Epoch 9/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8159 - loss: 0.4252
# Epoch 10/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8268 - loss: 0.4073
# Epoch 11/100
# ...

# %%
y_pred = ann.predict(x_test)
y_pred = (y_pred > 0.5)
y_pred
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
#Accuracy Score Classification report and confusion matrix
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
accuracy_score(y_test, y_pred)
# Out:
# 0.8613333333333333

# %%
print('Confusion Matrix:')
cm=confusion_matrix(y_test,y_pred)

print(confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[2288  128]
#  [ 288  296]]

# %%
print(cm)
# Out:
# [[2288  128]
#  [ 288  296]]

# %%
print('classification report')
print(classification_report(y_test, y_pred))
# Out:
# classification report
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92      2416
#            1       0.70      0.51      0.59       584
#
#     accuracy                           0.86      3000
#    macro avg       0.79      0.73      0.75      3000
# weighted avg       0.85      0.86      0.85      3000

# %%
import seaborn as sns
sns.heatmap(cm,annot=True)
# Out:
# <Axes: >
